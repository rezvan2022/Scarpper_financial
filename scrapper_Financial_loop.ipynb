# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import numpy as np
import csv
import bs4 as bs
import urllib.request
from selenium.common.exceptions import NoSuchElementException

# %%
input_df=pd.read_csv('constituents-financials_csv.csv')
input_df
# Out:
#     Symbol                    Name                  Sector  Current ratio  \
# 0      MMM              3M Company             Industrials            NaN
# 1      AOS         A.O. Smith Corp             Industrials            NaN
# 2      ABT     Abbott Laboratories             Health Care            NaN
# 3     ABBV             AbbVie Inc.             Health Care            NaN
# 4      ACN           Accenture plc  Information Technology            NaN
# ..     ...                     ...                     ...            ...
# 500    XYL              Xylem Inc.             Industrials            NaN
# 501    YUM         Yum! Brands Inc  Consumer Discretionary            NaN
# 502    ZBH  Zimmer Biomet Holdings             Health Care            NaN
# 503   ZION           Zions Bancorp              Financials            NaN
# 504    ZTS                  Zoetis             Health Care            NaN
#
#      Current ratio.1
# 0                NaN
# 1                NaN
# ...

# %%
brower=""
#for i in range(0,len(input_df['Symbol'])):
for i in range(198,len(input_df['Symbol'])):    
    #url = f'https://www.macrotrends.net/stocks/charts/{input_df.iloc[i][0]}/{input_df.iloc[i][1]}/financial-ratios'
    brower = webdriver.Chrome(ChromeDriverManager().install())
    #brower.get(url)
    ##########################################################

    try:
     urlg = f'https://www.macrotrends.net/stocks/charts/{input_df.iloc[i][0]}/{input_df.iloc[i][1]}/financial-ratios'
     brower.get(urlg)
     table = brower.find_element_by_id('wrapperjqxgrid')
    except NoSuchElementException:
        brower.quit()
        brower = webdriver.Chrome(ChromeDriverManager().install())
        i=int(i+1)
        urlg = f'https://www.macrotrends.net/stocks/charts/{input_df.iloc[i][0]}/{input_df.iloc[i][1]}/financial-ratios'
        brower.get(urlg)
        table = brower.find_element_by_id('wrapperjqxgrid') 
    

    table1=table.get_attribute('innerText')
    len(table1)
    table2=list(table1)
    table2=table1.splitlines()
    type(table2)
    len(table2)
    table2
    ##########################################################
    col = brower.find_element_by_id('columntablejqxgrid')
    col=col.get_attribute('innerText')
    col=col.splitlines()
    t=len(col)
    t=int(t)
    ##########################################################
    df = pd.DataFrame (table2)
    tt=len(df)
    tt=tt/t
    tt=int(tt)
    ##########################################################
    # importing library
  
    
    # initializing list
    lst = df
    
    # converting list to array
    try:
     table3 = np.asarray(lst).reshape(tt,t)

    except ValueError:
         lst=lst[0:len(lst)-1]
         table3 = np.asarray(lst).reshape(tt,t)
    
    # displaying list
    #print ("List:", lst)
    
    # displaying array
    print ("arr: ", table3)
    table3.shape


    with open(f'{input_df.iloc[i][1]}.csv','w') as f:
        writer = csv.writer(f)
        writer.writerows(table3)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 109.0.5414
# [WDM] - Get LATEST chromedriver version for 109.0.5414 google-chrome
# [WDM] - Driver [C:\Users\r.abdollahi\.wdm\drivers\chromedriver\win32\109.0.5414.74\chromedriver.exe] found in cache
# C:\Users\r.abdollahi\AppData\Local\Temp\ipykernel_23924\830002419.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   brower = webdriver.Chrome(ChromeDriverManager().install())
# C:\Users\r.abdollahi\AppData\Local\Temp\ipykernel_23924\830002419.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table = brower.find_element_by_id('wrapperjqxgrid')
# C:\Users\r.abdollahi\AppData\Local\Temp\ipykernel_23924\830002419.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   col = brower.find_element_by_id('columntablejqxgrid')
# ...
